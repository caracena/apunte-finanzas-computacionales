# %% [markdown]
# # 1. Carga de datos finacieros

# %% [markdown]
# ## Cargando datos de yfinance

# %%
# !pip install yfinance --quiet

import pandas as pd
import yfinance as yf

# %% [markdown]
# ### Descargar datos históricos OHLCV

# %% [markdown]
# La siguiente celda de código utiliza la biblioteca `yfinance` para descargar datos históricos de precios de acciones de IBM. El método `yf.download()` obtiene los datos OHLCV (Open, High, Low, Close, Volume) para el ticker "IBM". El parámetro `auto_adjust=True` ajusta automáticamente los precios de apertura, máximo, mínimo y cierre por dividendos y divisiones de acciones. Finalmente, `IBM.head()` muestra las primeras filas del DataFrame resultante.

# %%
IBM = yf.download("IBM", auto_adjust = True) #Descarga datos históricos, lo descarga en pd
IBM.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open   Volume
# Ticker             IBM         IBM         IBM         IBM      IBM
# Date
# 2025-09-15  256.239990  259.049988  254.000000  254.020004  4028400
# 2025-09-16  257.519989  258.000000  254.410004  256.260010  2719900
# 2025-09-17  259.079987  260.959991  257.010010  257.500000  3974800
# 2025-09-18  265.000000  265.230011  256.799988  258.859985  4988400
# 2025-09-19  266.399994  267.869995  263.640015  266.049988  9858100

# %% [markdown]
# ### Usando el método `Ticker`
#
# El método `download` solo permite descargar datos de OHLCV. Sin embargo, `yfinance` tiene el método `Ticker`, que permite descargar gran parte de la información contenida en `yfinance`.

# %%
AAPL = yf.Ticker("AAPL")
AAPL
# Out:
# yfinance.Ticker object <AAPL>

# %%
AAPL_data = AAPL.history()
AAPL_data.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-09-15 00:00:00-04:00  237.000000  238.190002  235.029999  236.699997
# 2025-09-16 00:00:00-04:00  237.179993  241.220001  236.320007  238.149994
# 2025-09-17 00:00:00-04:00  238.970001  240.100006  237.729996  238.990005
# 2025-09-18 00:00:00-04:00  239.970001  241.199997  236.649994  237.880005
# 2025-09-19 00:00:00-04:00  241.229996  246.300003  240.210007  245.500000
#
#                               Volume  Dividends  Stock Splits
# Date
# 2025-09-15 00:00:00-04:00   42699500        0.0           0.0
# 2025-09-16 00:00:00-04:00   63421100        0.0           0.0
# 2025-09-17 00:00:00-04:00   46508000        0.0           0.0
# 2025-09-18 00:00:00-04:00   44249600        0.0           0.0
# 2025-09-19 00:00:00-04:00  163741300        0.0           0.0

# %% [markdown]
# La tabla resultante contiene los datos históricos de precios de las acciones de AAPL con las siguientes columnas:
#
# *   **Open**: Precio de apertura de la acción en un día determinado.
# *   **High**: Precio máximo que alcanzó la acción en un día determinado.
# *   **Low**: Precio mínimo que alcanzó la acción en un día determinado.
# *   **Close**: Precio de cierre de la acción en un día determinado.
# *   **Volume**: Volumen de acciones negociadas en un día determinado.
# *   **Dividends**: Cantidad de dividendos pagados en un día determinado.
# *   **Stock Splits**: Factor de división de acciones aplicado en un día determinado.

# %%
AAPL_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21 entries, 2025-09-15 00:00:00-04:00 to 2025-10-13 00:00:00-04:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          21 non-null     float64
#  1   High          21 non-null     float64
#  2   Low           21 non-null     float64
#  3   Close         21 non-null     float64
#  4   Volume        21 non-null     int64
#  5   Dividends     21 non-null     float64
#  6   Stock Splits  21 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 1.3 KB

# %% [markdown]
# **Función `history`:**
# ```python
# AAPL.history(period="1mo", interval="1d",
#                 start=None, end=None,
#                 auto_adjust=True, keepna=False)
# ```
#
# **Parámetros (más importantes):**
#
# ```
# period : str
#     Valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
#     Either Use period parameter or use start and end
#
# interval : str
#     Valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
#     Intraday data cannot extend last 60 days
#
# start: str
#     Download start date string (YYYY-MM-DD) or _datetime, inclusive.
#     Default is 99 years ago
#     E.g. for start="2020-01-01", the first data point will be on "2020-01-01"
#
# end: str
#     Download end date string (YYYY-MM-DD) or _datetime, exclusive.
#     Default is now
#     E.g. for end="2023-01-01", the last data point will be on "2022-12-31"
#
# auto_adjust: bool
#     Adjust all OHLC automatically? Default is True
#
# keepna: bool
#     Keep NaN rows returned by Yahoo?
#     Default is False
#
# ```

# %% [markdown]
# La siguiente celda de código muestra cómo acceder a la información sobre las actualizaciones y degradaciones de calificación de una acción. El atributo `upgrades_downgrades` del objeto `Ticker` devuelve un DataFrame con detalles como la firma que emitió la calificación, la calificación anterior y nueva, la acción realizada (actualización, degradación, inicio de cobertura, etc.), el precio objetivo asociado y las fechas de la calificación.

# %%
AAPL.upgrades_downgrades
# Out:
#                                    Firm       ToGrade   FromGrade Action  \
# GradeDate
# 2025-10-03 12:50:53           Jefferies  Underperform        Hold   down
# 2025-10-02 12:45:02      Morgan Stanley    Overweight  Overweight   main
# 2025-10-01 12:20:24      Seaport Global           Buy               init
# 2025-09-26 15:57:54  Evercore ISI Group    Outperform  Outperform   main
# 2025-09-22 09:23:09             Wedbush    Outperform  Outperform   main
# ...                                 ...           ...         ...    ...
# 2016-09-22 10:22:56              Nomura           Buy               main
# 2016-09-16 11:12:49                CLSA           Buy               main
# 2016-09-15 12:10:08       Credit Suisse    Outperform               main
# 2016-09-15 12:08:11                BTIG           Buy               main
# 2012-09-12 11:51:00       Hudson Square           Buy               main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# ...

# %% [markdown]
# #### Información de la empresa

# %%
AAPL.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %% [markdown]
# Llamando a la descripción de la empresa:

# %%
AAPL.info["longBusinessSummary"]
# Out:
# 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscripti
# ...

# %% [markdown]
# #### Balance anual y trimestral

# %% [markdown]
# La siguiente celda de código muestra el balance general anual de la empresa.

# %%
#anual
AAPL.balance_sheet
# Out:
#                                                     2024-09-30    2023-09-30  \
# Treasury Shares Number                                     NaN  0.000000e+00
# Ordinary Shares Number                            1.511679e+10  1.555006e+10
# Share Issued                                      1.511679e+10  1.555006e+10
# Net Debt                                          7.668600e+10  8.112300e+10
# Total Debt                                        1.066290e+11  1.110880e+11
# ...                                                        ...           ...
# Cash Cash Equivalents And Short Term Investments  6.517100e+10  6.155500e+10
# Other Short Term Investments                      3.522800e+10  3.159000e+10
# Cash And Cash Equivalents                         2.994300e+10  2.996500e+10
# Cash Equivalents                                  2.744000e+09  1.606000e+09
# Cash Financial                                    2.719900e+10  2.835900e+10
#
# ...

# %%
AAPL.balance_sheet.index.values.tolist()
# Out:
# ['Treasury Shares Number',
#  'Ordinary Shares Number',
#  'Share Issued',
#  'Net Debt',
#  'Total Debt',
#  'Tangible Book Value',
#  'Invested Capital',
#  'Working Capital',
#  'Net Tangible Assets',
#  'Capital Lease Obligations',
#  'Common Stock Equity',
#  'Total Capitalization',
#  'Total Equity Gross Minority Interest',
#  'Stockholders Equity',
#  'Gains Losses Not Affecting Retained Earnings',
#  'Other Equity Adjustments',
#  'Retained Earnings',
#  'Capital Stock',
#  'Common Stock',
#  'Total Liabilities Net Minority Interest',
#  'Total Non Current Liabilities Net Minority Interest',
#  'Other Non Current Liabilities',
#  'Tradeand Other Payables Non Current',
#  'Long Term Debt And Capital Lease Obligation',
#  'Long Term Capital Lease Obligation',
#  'Long Term Debt',
#  'Current Liabilities',
#  'Other Current Liabilities',
#  'Current Deferred Liabilities',
#  'Current Deferred Revenue',
#  'Current Debt And Capital Lease Obligation',
# ...

# %%
AAPL.balance_sheet.loc['Total Assets', '2024-09-30'] == AAPL.balance_sheet.loc['Total Liabilities Net Minority Interest', '2024-09-30'] + AAPL.balance_sheet.loc['Total Equity Gross Minority Interest', '2024-09-30']
# Out:
# np.True_

# %%
# Trimestral
AAPL.quarterly_balance_sheet
# Out:
#                                                     2025-06-30    2025-03-31  \
# Ordinary Shares Number                            1.485672e+10  1.493932e+10
# Share Issued                                      1.485672e+10  1.493932e+10
# Net Debt                                          6.542900e+10  7.002400e+10
# Total Debt                                        1.016980e+11  9.818600e+10
# Tangible Book Value                               6.583000e+10  6.679600e+10
# ...                                                        ...           ...
# Cash Cash Equivalents And Short Term Investments  5.537200e+10  4.849800e+10
# Other Short Term Investments                      1.910300e+10  2.033600e+10
# Cash And Cash Equivalents                         3.626900e+10  2.816200e+10
# Cash Equivalents                                  9.583000e+09  3.101000e+09
# Cash Financial                                    2.668600e+10  2.506100e+10
#
# ...

# %% [markdown]
# #### Estado de resultados anual y trimestral

# %%
# Anual
AAPL.income_stmt
# Out:
#                                                       2024-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  2.410000e-01
# Normalized EBITDA                                   1.346610e+11
# Net Income From Continuing Operation Net Minori...  9.373600e+10
# Reconciled Depreciation                             1.144500e+10
# Reconciled Cost Of Revenue                          2.103520e+11
# EBITDA                                              1.346610e+11
# EBIT                                                1.232160e+11
# Net Interest Income                                          NaN
# Interest Expense                                             NaN
# Interest Income                                              NaN
# Normalized Income                                   9.373600e+10
# Net Income From Continuing And Discontinued Ope...  9.373600e+10
# ...

# %%
# Trimestral
AAPL.quarterly_income_stmt
# Out:
#                                                       2025-06-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.640000e-01
# Normalized EBITDA                                   3.103200e+10
# Net Income From Continuing Operation Net Minori...  2.343400e+10
# Reconciled Depreciation                             2.830000e+09
# Reconciled Cost Of Revenue                          5.031800e+10
# EBITDA                                              3.103200e+10
# EBIT                                                2.820200e+10
# Normalized Income                                   2.343400e+10
# Net Income From Continuing And Discontinued Ope...  2.343400e+10
# Total Expenses                                      6.583400e+10
# Total Operating Income As Reported                  2.820200e+10
# Diluted Average Shares                              1.494818e+10
# ...

# %% [markdown]
# #### Noticias

# %% [markdown]
# La siguiente celda de código accede a la primera noticia disponible para el ticker AAPL.

# %%
AAPL.news[0]
# Out:
# {'id': '7faebfb6-6893-3589-97ae-e1f8bbbf324e',
#  'content': {'id': '7faebfb6-6893-3589-97ae-e1f8bbbf324e',
#   'contentType': 'STORY',
#   'title': 'Jefferies flags tariff risk to Apple margins',
#   'description': '',
#   'summary': 'Investing.com -- Jefferies warned that new U.S. tariff threats could squeeze Apple’s margins on the iPhone 17, saying the tech giant may face a hit to earnings if imports from China lose their current exemption.',
#   'pubDate': '2025-10-13T14:37:37Z',
#   'displayTime': '2025-10-13T14:37:37Z',
#   'isHosted': True,
#   'bypassModal': False,
#   'previewUrl': None,
#   'thumbnail': None,
#   'provider': {'displayName': 'Investing.com',
#    'url': 'https://www.investing.com/'},
#   'canonicalUrl': {'url': 'https://finance.yahoo.com/news/jefferies-flags-tariff-risk-apple-143737558.html',
#    'site': 'finance',
#    'region': 'US',
#    'lang': 'en-US'},
# ...

# %%
AAPL.news[0]['content']['summary']
# Out:
# 'Investing.com -- Jefferies warned that new U.S. tariff threats could squeeze Apple’s margins on the iPhone 17, saying the tech giant may face a hit to earnings if imports from China lose their current exemption.'

# %%
len(AAPL.news)
# Out:
# 10

# %% [markdown]
# ## Cargando datos desde CoinGecko

# %%
# !pip install -U pycoingecko --quiet

# %%
from pycoingecko import CoinGeckoAPI
from datetime import datetime
import pandas as pd

# %% [markdown]
# La siguiente celda de código inicializa la API de CoinGecko. La celda subsiguiente descarga datos históricos de OHLC (Open, High, Low, Close) para Bitcoin en dólares estadounidenses para los últimos 14 días utilizando la API de CoinGecko, los carga en un DataFrame de pandas, renombra las columnas y convierte la columna de fecha a un formato de fecha y hora adecuado. Finalmente, muestra el DataFrame resultante.

# %%
cg = CoinGeckoAPI()

# %%
ohlc = cg.get_coin_ohlc_by_id(
    id="bitcoin", vs_currency="usd", days="14"
)
ohlc_df = pd.DataFrame(ohlc)
ohlc_df.columns = ["date", "open", "high", "low", "close"]
ohlc_df["date"] = pd.to_datetime(ohlc_df["date"], unit="ms")
ohlc_df
# Out:
#                   date      open      high       low     close
# 0  2025-09-29 20:00:00  113873.0  114332.0  113599.0  114268.0
# 1  2025-09-30 00:00:00  114218.0  114411.0  114072.0  114309.0
# 2  2025-09-30 04:00:00  114327.0  114762.0  114119.0  114388.0
# 3  2025-09-30 08:00:00  114380.0  114380.0  113678.0  113792.0
# 4  2025-09-30 12:00:00  113743.0  113749.0  112736.0  113093.0
# ..                 ...       ...       ...       ...       ...
# 79 2025-10-13 00:00:00  114658.0  115546.0  114541.0  115190.0
# 80 2025-10-13 04:00:00  115061.0  115792.0  114822.0  114822.0
# 81 2025-10-13 08:00:00  115022.0  115570.0  114592.0  115298.0
# 82 2025-10-13 12:00:00  115346.0  115454.0  113968.0  114447.0
# 83 2025-10-13 16:00:00  114189.0  115479.0  114005.0  114460.0
#
# [84 rows x 5 columns]

# %% [markdown]
# El método `get_coin_ohlc_by_id` se usa para obtener datos históricos de OHLC para una criptomoneda específica.
#
# **Parámetros:**
#
# *   `id`: El ID de la criptomoneda (ej. "bitcoin").
# *   `vs_currency`: La moneda de referencia para los precios (ej. "usd").
# *   `days`: El número de días de datos históricos a obtener.
#
# Cabe mencionar que la API tiene algunas limitaciones:
# * Solo podemos descargar datos de un número predefinido de días. Podemos seleccionar una de las siguientes opciones: 1/7/14/30/90/180/365/máx.
# * Las velas OHLC se muestrean con una frecuencia variable según el horizonte solicitado.
# Se muestrean cada 30 minutos para solicitudes de 1 o 2 días. Entre 3 y 30 días, se muestrean cada 4 horas. A partir de 30 días, se muestrean cada 4 días.

# %% [markdown]
# ### Monedas en tendencia

# %% [markdown]
# La siguiente celda de código utiliza el método `get_search_trending()` de la API de CoinGecko para obtener una lista de las criptomonedas que están en tendencia.

# %%
trending_coins = cg.get_search_trending()
(
    pd.DataFrame([coin["item"] for coin in trending_coins["coins"]])
    .drop(columns=["thumb", "small", "large", "data"])
)
# Out:
#                 id  coin_id            name symbol  market_cap_rank  \
# 0             ergo     2484            Ergo    ERG              720
# 1           havven     3406       Synthetix    SNX              131
# 2        bittensor    28452       Bittensor    TAO               42
# 3          aster-2    69040           Aster  ASTER               54
# 4      hyperliquid    50882     Hyperliquid   HYPE               20
# 5   pudgy-penguins    52622  Pudgy Penguins  PENGU               85
# 6            zcash      486           Zcash    ZEC               43
# 7    chainopera-ai    69447   ChainOpera AI   COAI               95
# 8            euler    26149           Euler    EUL              364
# 9           ethena    36530          Ethena    ENA               51
# 10             sui    26375             Sui    SUI               22
# 11        ethereum      279        Ethereum    ETH                2
# 12         bitcoin        1         Bitcoin    BTC                1
# ...

# %% [markdown]
# ### Precio actual

# %% [markdown]
# Las siguientes dos celdas de código demuestran cómo obtener el precio actual de una o varias criptomonedas en diferentes divisas utilizando el método `get_price()` de la API de CoinGecko.

# %%
cg.get_price(ids="bitcoin", vs_currencies="usd")
# Out:
# {'bitcoin': {'usd': 114537}}

# %%
cg.get_price(ids=["bitcoin", "ethereum"], vs_currencies=["usd", "eur"])
# Out:
# {'bitcoin': {'usd': 114512, 'eur': 98972},
#  'ethereum': {'usd': 4150.64, 'eur': 3587.37}}

# %% [markdown]
# La siguiente celda de código obtiene el precio actual de Bitcoin en USD, incluyendo la capitalización de mercado, el volumen de las últimas 24 horas, el cambio porcentual en las últimas 24 horas y la hora de la última actualización.

# %%
cg.get_price(ids="bitcoin", vs_currencies="usd",
             include_market_cap=True,
             include_24hr_vol=True,
             include_24hr_change=True,
             include_last_updated_at=True)
# Out:
# {'bitcoin': {'usd': 114517,
#   'usd_market_cap': 2284628864150.7544,
#   'usd_24h_vol': 85636314799.66135,
#   'usd_24h_change': -0.029883262985937145,
#   'last_updated_at': 1760373782}}

# %% [markdown]
# ### Listado de monedas y precios

# %%
pd.DataFrame(cg.get_coins_list())
# Out:
#                                            id  \
# 0                                           _
# 1                                 000-capital
# 2      01111010011110000110001001110100-token
# 3                                      0chain
# 4                         0-knowledge-network
# ...                                       ...
# 19203                           zygo-the-frog
# 19204                               zyncoin-2
# 19205                                zynecoin
# 19206                                  zyro-2
# 19207                z-z-z-z-z-fehu-z-z-z-z-z
#
#                                  symbol                              name
# 0                                   gib                        ༼ つ ◕_◕ ༽つ
# 1                                   000                       000 Capital
# 2      01111010011110000110001001110100  01111010011110000110001001110100
# 3                                   zcn                               Zus
# ...

# %%
pd.DataFrame(cg.get_coins_markets(vs_currency="usd"))
# Out:
#                     id symbol                name  \
# 0              bitcoin    btc             Bitcoin
# 1             ethereum    eth            Ethereum
# 2               tether   usdt              Tether
# 3          binancecoin    bnb                 BNB
# 4               ripple    xrp                 XRP
# ..                 ...    ...                 ...
# 95  lombard-staked-btc   lbtc  Lombard Staked BTC
# 96  renzo-restaked-eth  ezeth  Renzo Restaked ETH
# 97       quant-network    qnt               Quant
# 98      official-trump  trump      Official Trump
# 99            pax-gold   paxg            PAX Gold
#
#                                                 image  current_price  \
# 0   https://coin-images.coingecko.com/coins/images...     114509.000
# 1   https://coin-images.coingecko.com/coins/images...       4150.520
# 2   https://coin-images.coingecko.com/coins/images...          1.001
# 3   https://coin-images.coingecko.com/coins/images...       1277.780
# ...
