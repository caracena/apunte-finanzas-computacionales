# %% [markdown]
# # 1. Yahoo! Finance

# %%
# %pip install yfinance

import pandas as pd
import yfinance as yf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting yfinance
#   Downloading yfinance-0.2.66-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from yfinance) (2.3.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: requests>=2.31 in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from yfinance) (4.3.8)
# Requirement already satisfied: pytz>=2022.5 in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.6-py313-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.2.tar.gz (949 kB)
#      ---------------------------------------- 0.0/949.2 kB ? eta -:--:--
#      ---------------------------------------- 949.2/949.2 kB 7.2 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from yfinance) (4.13.5)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl.metadata (13 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Downloading protobuf-6.32.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from curl_cffi>=0.7->yfinance) (2025.8.3)
# Requirement already satisfied: pycparser in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.31->yfinance) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Downloading yfinance-0.2.66-py2.py3-none-any.whl (123 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.6 MB 3.3 MB/s eta 0:00:01
#    -------------------------------- ------- 1.3/1.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 3.3 MB/s  0:00:00
# Downloading frozendict-2.4.6-py313-none-any.whl (16 kB)
# Downloading protobuf-6.32.1-cp310-abi3-win_amd64.whl (435 kB)
# Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl (176 kB)
# Building wheels for collected packages: multitasking, peewee
#   Building wheel for multitasking (pyproject.toml): started
#   Building wheel for multitasking (pyproject.toml): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15703 sha256=4ba864b3f16e8e35fe6705ffe89d9200711cdf65c485c11261c45963ed8b5d81
#   Stored in directory: c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\1e\df\0f\e2bbb22d689b30c681feb5410ab64a2523437b34c8ecfc6476
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.18.2-py3-none-any.whl size=139153 sha256=0a25daea0320a9e0cbb3675637d5206579d3ac608e42c1593c9cdb17b979071d
#   Stored in directory: c:\users\airow\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\1c\48\cc\00b7d0e7defa21a58915654917c89eaedd32a6e614d8e4ad92
# Successfully built multitasking peewee
# Installing collected packages: peewee, multitasking, websockets, protobuf, frozendict, curl_cffi, yfinance
#
#    ---------------------------------------- 0/7 [peewee]
#    ---------------------------------------- 0/7 [peewee]
#    ---------------------------------------- 0/7 [peewee]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ---------------------------- ----------- 5/7 [curl_cffi]
#    ---------------------------- ----------- 5/7 [curl_cffi]
#    ---------------------------- ----------- 5/7 [curl_cffi]
#    ---------------------------- ----------- 5/7 [curl_cffi]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------------- 7/7 [yfinance]
#
# Successfully installed curl_cffi-0.13.0 frozendict-2.4.6 multitasking-0.0.12 peewee-3.18.2 protobuf-6.32.1 websockets-15.0.1 yfinance-0.2.66
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script websockets.exe is installed in 'C:\Users\airow\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script sample.exe is installed in 'C:\Users\airow\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %% [markdown]
# ## Descargar datos históricos OHLCV

# %%
IBM = yf.download("IBM", auto_adjust = True) #Descarga datos históricos, lo descarga en pd
IBM.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open   Volume
# Ticker             IBM         IBM         IBM         IBM      IBM
# Date
# 2025-09-03  244.100006  244.250000  239.410004  240.020004  3163200
# 2025-09-04  247.179993  249.279999  242.850006  245.419998  4765100
# 2025-09-05  248.529999  249.029999  245.449997  248.229996  3147500
# 2025-09-08  256.089996  257.149994  247.020004  248.630005  6940300
# 2025-09-09  259.109985  260.660004  254.880005  256.119995  4931100

# %% [markdown]
# ## Usando el método `Ticker`
#
# El método `download` solo permite descargar datos de OHLCV. Sin embargo, `yfinance` tiene el método `Ticker`, que permite descargar gran parte de la información contenida en `yfinance`.

# %%
AAPL = yf.Ticker("AAPL")
AAPL
# Out:
# yfinance.Ticker object <AAPL>

# %%
AAPL_data = AAPL.history()
AAPL_data.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-09-03 00:00:00-04:00  237.210007  238.850006  234.360001  238.470001
# 2025-09-04 00:00:00-04:00  238.449997  239.899994  236.740005  239.779999
# 2025-09-05 00:00:00-04:00  240.000000  241.320007  238.490005  239.690002
# 2025-09-08 00:00:00-04:00  239.300003  240.149994  236.339996  237.880005
# 2025-09-09 00:00:00-04:00  237.000000  238.779999  233.360001  234.350006
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-09-03 00:00:00-04:00  66427800        0.0           0.0
# 2025-09-04 00:00:00-04:00  47549400        0.0           0.0
# 2025-09-05 00:00:00-04:00  54870400        0.0           0.0
# 2025-09-08 00:00:00-04:00  48999500        0.0           0.0
# 2025-09-09 00:00:00-04:00  66313900        0.0           0.0

# %%
AAPL_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23 entries, 2025-09-03 00:00:00-04:00 to 2025-10-03 00:00:00-04:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          23 non-null     float64
#  1   High          23 non-null     float64
#  2   Low           23 non-null     float64
#  3   Close         23 non-null     float64
#  4   Volume        23 non-null     int64
#  5   Dividends     23 non-null     float64
#  6   Stock Splits  23 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 1.4 KB

# %% [markdown]
# **Función `history`:**
# ```python
# AAPL.history(period="1mo", interval="1d",
#                 start=None, end=None, prepost=False, actions=True,
#                 auto_adjust=True, back_adjust=False, keepna=False)
# ```
#
# **Parámetros (más importantes):**
#
# ```
# period : str
#     Valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
#     Either Use period parameter or use start and end
#
# interval : str
#     Valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
#     Intraday data cannot extend last 60 days
#
# start: str
#     Download start date string (YYYY-MM-DD) or _datetime, inclusive.
#     Default is 99 years ago
#     E.g. for start="2020-01-01", the first data point will be on "2020-01-01"
#
# end: str
#     Download end date string (YYYY-MM-DD) or _datetime, exclusive.
#     Default is now
#     E.g. for end="2023-01-01", the last data point will be on "2022-12-31"
#
# prepost : bool
#     Include Pre and Post market data in results?
#     Default is False
#
# auto_adjust: bool
#     Adjust all OHLC automatically? Default is True
#
# keepna: bool
#     Keep NaN rows returned by Yahoo?
#     Default is False
#
# ```

# %%
AAPL.upgrades_downgrades
# Out:
#                                    Firm       ToGrade   FromGrade Action  \
# GradeDate
# 2025-10-03 12:50:53           Jefferies  Underperform        Hold   down
# 2025-10-02 12:45:02      Morgan Stanley    Overweight  Overweight   main
# 2025-10-01 12:20:24      Seaport Global           Buy               init
# 2025-09-26 15:57:54  Evercore ISI Group    Outperform  Outperform   main
# 2025-09-22 09:23:09             Wedbush    Outperform  Outperform   main
# ...                                 ...           ...         ...    ...
# 2016-09-22 10:22:56              Nomura           Buy               main
# 2016-09-16 11:12:49                CLSA           Buy               main
# 2016-09-15 12:10:08       Credit Suisse    Outperform               main
# 2016-09-15 12:08:11                BTIG           Buy               main
# 2012-09-12 11:51:00       Hudson Square           Buy               main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-10-03 12:50:53            Lowers              205.16            205.82
# 2025-10-02 12:45:02            Raises              298.00            240.00
# 2025-10-01 12:20:24         Announces              310.00              0.00
# 2025-09-26 15:57:54            Raises              290.00            260.00
# 2025-09-22 09:23:09            Raises              310.00            270.00
# ...                               ...                 ...               ...
# 2016-09-22 10:22:56            Raises              135.00            120.00
# 2016-09-16 11:12:49            Raises               32.50             30.00
# 2016-09-15 12:10:08         Maintains              150.00              0.00
# 2016-09-15 12:08:11            Raises              133.00            124.00
# 2012-09-12 11:51:00            Raises              900.00            700.00
#
# [958 rows x 7 columns]

# %% [markdown]
# ### Información de la empresa

# %%
AAPL.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#  'fullTimeEmployees': 150000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Timothy D. Cook',
#    'age': 63,
#    'title': 'CEO & Director',
#    'yearBorn': 1961,
#    'fiscalYear': 2024,
#    'totalPay': 16520856,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jeffrey E. Williams',
#    'age': 60,
#    'title': 'Senior Vice President of Design, Watch, & Health',
#    'yearBorn': 1964,
#    'fiscalYear': 2024,
#    'totalPay': 5020737,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Kevan  Parekh',
#    'age': 52,
#    'title': 'Senior VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Sabih  Khan',
#    'title': 'Chief Operating Officer',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Chris  Kondo',
#    'title': 'Senior Director of Corporate Accounting',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Suhasini  Chandramouli',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Kristin Huguet Quayle',
#    'title': 'Vice President of Worldwide Communications',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Greg  Joswiak',
#    'title': 'Senior Vice President of Worldwide Marketing',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Adrian  Perica',
#    'age': 50,
#    'title': 'Vice President of Corporate Development',
#    'yearBorn': 1974,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Michael  Fenger',
#    'title': 'VP of Worldwide Sales',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 7,
#  'boardRisk': 1,
#  'compensationRisk': 3,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 1,
#  'governanceEpochDate': 1759276800,
#  'compensationAsOfEpochDate': 1735603200,
#  'irWebsite': 'http://investor.apple.com/',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 257.13,
#  'open': 254.665,
#  'dayLow': 253.96,
#  'dayHigh': 259.24,
#  'regularMarketPreviousClose': 257.13,
#  'regularMarketOpen': 254.665,
#  'regularMarketDayLow': 253.96,
#  'regularMarketDayHigh': 259.24,
#  'dividendRate': 1.04,
#  'dividendYield': 0.4,
#  'exDividendDate': 1754870400,
#  'payoutRatio': 0.1533,
#  'fiveYearAvgDividendYield': 0.54,
#  'beta': 1.094,
#  'trailingPE': 39.22012,
#  'forwardPE': 31.05516,
#  'volume': 38941141,
#  'regularMarketVolume': 38941141,
#  'averageVolume': 55129773,
#  'averageVolume10days': 64225910,
#  'averageDailyVolume10Day': 64225910,
#  'bid': 257.03,
#  'ask': 259.98,
#  'bidSize': 4,
#  'askSize': 4,
#  'marketCap': 3829835497472,
#  'fiftyTwoWeekLow': 169.21,
#  'fiftyTwoWeekHigh': 260.1,
#  'allTimeHigh': 260.1,
#  'allTimeLow': 0.049107,
#  'priceToSalesTrailing12Months': 9.372495,
#  'fiftyDayAverage': 231.8392,
#  'twoHundredDayAverage': 222.13695,
#  'trailingAnnualDividendRate': 1.01,
#  'trailingAnnualDividendYield': 0.003927974,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 3862235447296,
#  'profitMargins': 0.24295999,
#  'floatShares': 14814419318,
#  'sharesOutstanding': 14840390000,
#  'sharesShort': 118199377,
#  'sharesShortPriorMonth': 127079143,
#  'sharesShortPreviousMonthDate': 1755216000,
#  'dateShortInterest': 1757894400,
#  'sharesPercentSharesOut': 0.008,
#  'heldPercentInsiders': 0.0197,
#  'heldPercentInstitutions': 0.63625,
#  'shortRatio': 2.47,
#  'shortPercentOfFloat': 0.008,
#  'impliedSharesOutstanding': 14840970951,
#  'bookValue': 4.431,
#  'priceToBook': 58.241566,
#  'lastFiscalYearEnd': 1727481600,
#  'nextFiscalYearEnd': 1759017600,
#  'mostRecentQuarter': 1751068800,
#  'earningsQuarterlyGrowth': 0.093,
#  'netIncomeToCommon': 99280003072,
#  'trailingEps': 6.58,
#  'forwardEps': 8.31,
#  'lastSplitFactor': '4:1',
#  'lastSplitDate': 1598832000,
#  'enterpriseToRevenue': 9.452,
#  'enterpriseToEbitda': 27.257,
#  '52WeekChange': 0.13373017,
#  'SandP52WeekChange': 0.16766965,
#  'lastDividendValue': 0.26,
#  'lastDividendDate': 1754870400,
#  'quoteType': 'EQUITY',
#  'currentPrice': 258.0684,
#  'targetHighPrice': 310.0,
#  'targetLowPrice': 175.0,
#  'targetMeanPrice': 246.2347,
#  'targetMedianPrice': 245.0,
#  'recommendationMean': 2.0,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 41,
#  'totalCash': 55372001280,
#  'totalCashPerShare': 3.731,
#  'ebitda': 141696008192,
#  'totalDebt': 101698002944,
#  'quickRatio': 0.724,
#  'currentRatio': 0.868,
#  'totalRevenue': 408624988160,
#  'debtToEquity': 154.486,
#  'revenuePerShare': 27.173,
#  'returnOnAssets': 0.24545999,
#  'returnOnEquity': 1.49814,
#  'grossProfits': 190739005440,
#  'freeCashflow': 94873747456,
#  'operatingCashflow': 108564996096,
#  'earningsGrowth': 0.121,
#  'revenueGrowth': 0.096,
#  'grossMargins': 0.46678,
#  'ebitdaMargins': 0.34675997,
#  'operatingMargins': 0.29990998,
#  'financialCurrency': 'USD',
#  'symbol': 'AAPL',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'marketState': 'REGULAR',
#  'corporateActions': [],
#  'regularMarketTime': 1759520892,
#  'exchange': 'NMS',
#  'messageBoardId': 'finmb_24937',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'epsTrailingTwelveMonths': 6.58,
#  'epsForward': 8.31,
#  'epsCurrentYear': 7.39798,
#  'priceEpsCurrentYear': 34.88363,
#  'fiftyDayAverageChange': 26.229187,
#  'fiftyDayAverageChangePercent': 0.113135256,
#  'twoHundredDayAverageChange': 35.931442,
#  'twoHundredDayAverageChangePercent': 0.16175357,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '2.0 - Buy',
#  'cryptoTradeable': False,
#  'regularMarketChangePercent': 0.36494574,
#  'regularMarketPrice': 258.0684,
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 345479400000,
#  'regularMarketChange': 0.938385,
#  'regularMarketDayRange': '253.96 - 259.24',
#  'fullExchangeName': 'NasdaqGS',
#  'averageDailyVolume3Month': 55129773,
#  'fiftyTwoWeekLowChange': 88.85838,
#  'fiftyTwoWeekLowChangePercent': 0.5251367,
#  'fiftyTwoWeekRange': '169.21 - 260.1',
#  'fiftyTwoWeekHighChange': -2.0316162,
#  'fiftyTwoWeekHighChangePercent': -0.007810904,
#  'fiftyTwoWeekChangePercent': 13.373017,
#  'dividendDate': 1755129600,
#  'earningsTimestamp': 1761854400,
#  'earningsTimestampStart': 1761854400,
#  'earningsTimestampEnd': 1761854400,
#  'earningsCallTimestampStart': 1761858000,
#  'earningsCallTimestampEnd': 1761858000,
#  'isEarningsDateEstimate': False,
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'displayName': 'Apple',
#  'trailingPegRatio': 2.4662}

# %% [markdown]
# Llamando a la descripción de la empresa:

# %%
AAPL.info["longBusinessSummary"]
# Out:
# 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.'

# %% [markdown]
# ### Balance anual y trimestral

# %%
#anual
AAPL.balance_sheet
# Out:
#                                                     2024-09-30    2023-09-30  \
# Treasury Shares Number                                     NaN  0.000000e+00
# Ordinary Shares Number                            1.511679e+10  1.555006e+10
# Share Issued                                      1.511679e+10  1.555006e+10
# Net Debt                                          7.668600e+10  8.112300e+10
# Total Debt                                        1.066290e+11  1.110880e+11
# ...                                                        ...           ...
# Cash Cash Equivalents And Short Term Investments  6.517100e+10  6.155500e+10
# Other Short Term Investments                      3.522800e+10  3.159000e+10
# Cash And Cash Equivalents                         2.994300e+10  2.996500e+10
# Cash Equivalents                                  2.744000e+09  1.606000e+09
# Cash Financial                                    2.719900e+10  2.835900e+10
#
#                                                     2022-09-30    2021-09-30
# Treasury Shares Number                                     NaN           NaN
# Ordinary Shares Number                            1.594342e+10  1.642679e+10
# Share Issued                                      1.594342e+10  1.642679e+10
# Net Debt                                          9.642300e+10  8.977900e+10
# Total Debt                                        1.324800e+11  1.365220e+11
# ...                                                        ...           ...
# Cash Cash Equivalents And Short Term Investments  4.830400e+10  6.263900e+10
# Other Short Term Investments                      2.465800e+10  2.769900e+10
# Cash And Cash Equivalents                         2.364600e+10  3.494000e+10
# Cash Equivalents                                  5.100000e+09  1.763500e+10
# Cash Financial                                    1.854600e+10  1.730500e+10
#
# [68 rows x 4 columns]

# %%
AAPL.balance_sheet.index.values.tolist()
# Out:
# ['Treasury Shares Number',
#  'Ordinary Shares Number',
#  'Share Issued',
#  'Net Debt',
#  'Total Debt',
#  'Tangible Book Value',
#  'Invested Capital',
#  'Working Capital',
#  'Net Tangible Assets',
#  'Capital Lease Obligations',
#  'Common Stock Equity',
#  'Total Capitalization',
#  'Total Equity Gross Minority Interest',
#  'Stockholders Equity',
#  'Gains Losses Not Affecting Retained Earnings',
#  'Other Equity Adjustments',
#  'Retained Earnings',
#  'Capital Stock',
#  'Common Stock',
#  'Total Liabilities Net Minority Interest',
#  'Total Non Current Liabilities Net Minority Interest',
#  'Other Non Current Liabilities',
#  'Tradeand Other Payables Non Current',
#  'Long Term Debt And Capital Lease Obligation',
#  'Long Term Capital Lease Obligation',
#  'Long Term Debt',
#  'Current Liabilities',
#  'Other Current Liabilities',
#  'Current Deferred Liabilities',
#  'Current Deferred Revenue',
#  'Current Debt And Capital Lease Obligation',
#  'Current Capital Lease Obligation',
#  'Current Debt',
#  'Other Current Borrowings',
#  'Commercial Paper',
#  'Payables And Accrued Expenses',
#  'Payables',
#  'Total Tax Payable',
#  'Income Tax Payable',
#  'Accounts Payable',
#  'Total Assets',
#  'Total Non Current Assets',
#  'Other Non Current Assets',
#  'Non Current Deferred Assets',
#  'Non Current Deferred Taxes Assets',
#  'Investments And Advances',
#  'Other Investments',
#  'Investmentin Financial Assets',
#  'Available For Sale Securities',
#  'Net PPE',
#  'Accumulated Depreciation',
#  'Gross PPE',
#  'Leases',
#  'Other Properties',
#  'Machinery Furniture Equipment',
#  'Land And Improvements',
#  'Properties',
#  'Current Assets',
#  'Other Current Assets',
#  'Inventory',
#  'Receivables',
#  'Other Receivables',
#  'Accounts Receivable',
#  'Cash Cash Equivalents And Short Term Investments',
#  'Other Short Term Investments',
#  'Cash And Cash Equivalents',
#  'Cash Equivalents',
#  'Cash Financial']

# %%
AAPL.balance_sheet.loc['Total Assets', '2024-09-30'] == AAPL.balance_sheet.loc['Total Liabilities Net Minority Interest', '2024-09-30'] + AAPL.balance_sheet.loc['Total Equity Gross Minority Interest', '2024-09-30']
# Out:
# np.True_

# %%
# Trimestral
AAPL.quarterly_balance_sheet
# Out:
#                                                      2025-03-31  \
# Treasury Shares Number                                      NaN
# Ordinary Shares Number                            14939315000.0
# Share Issued                                      14939315000.0
# Net Debt                                          70024000000.0
# Total Debt                                        98186000000.0
# ...                                                         ...
# Cash Cash Equivalents And Short Term Investments  48498000000.0
# Other Short Term Investments                      20336000000.0
# Cash And Cash Equivalents                         28162000000.0
# Cash Equivalents                                   3101000000.0
# Cash Financial                                    25061000000.0
#
#                                                      2024-12-31  \
# Treasury Shares Number                                      NaN
# Ordinary Shares Number                            15037874000.0
# Share Issued                                      15037874000.0
# Net Debt                                          66500000000.0
# Total Debt                                        96799000000.0
# ...                                                         ...
# Cash Cash Equivalents And Short Term Investments  53775000000.0
# Other Short Term Investments                      23476000000.0
# Cash And Cash Equivalents                         30299000000.0
# Cash Equivalents                                   3226000000.0
# Cash Financial                                    27073000000.0
#
#                                                       2024-09-30  \
# Treasury Shares Number                                       NaN
# Ordinary Shares Number                             15116786000.0
# Share Issued                                       15116786000.0
# Net Debt                                           76686000000.0
# Total Debt                                        106629000000.0
# ...                                                          ...
# Cash Cash Equivalents And Short Term Investments   65171000000.0
# Other Short Term Investments                       35228000000.0
# Cash And Cash Equivalents                          29943000000.0
# Cash Equivalents                                    2744000000.0
# Cash Financial                                     27199000000.0
#
#                                                       2024-06-30  \
# Treasury Shares Number                                       NaN
# Ordinary Shares Number                             15222259000.0
# Share Issued                                       15222259000.0
# Net Debt                                           75739000000.0
# Total Debt                                        101304000000.0
# ...                                                          ...
# Cash Cash Equivalents And Short Term Investments   61801000000.0
# Other Short Term Investments                       36236000000.0
# Cash And Cash Equivalents                          25565000000.0
# Cash Equivalents                                    2699000000.0
# Cash Financial                                     22866000000.0
#
#                                                       2024-03-31 2023-12-31  \
# Treasury Shares Number                                       NaN        0.0
# Ordinary Shares Number                             15337686000.0        NaN
# Share Issued                                       15337686000.0        NaN
# Net Debt                                           71895000000.0        NaN
# Total Debt                                        104590000000.0        NaN
# ...                                                          ...        ...
# Cash Cash Equivalents And Short Term Investments   67150000000.0        NaN
# Other Short Term Investments                       34455000000.0        NaN
# Cash And Cash Equivalents                          32695000000.0        NaN
# Cash Equivalents                                    4468000000.0        NaN
# Cash Financial                                     28227000000.0        NaN
#
#                                                  2023-09-30
# Treasury Shares Number                                  0.0
# Ordinary Shares Number                                  NaN
# Share Issued                                            NaN
# Net Debt                                                NaN
# Total Debt                                              NaN
# ...                                                     ...
# Cash Cash Equivalents And Short Term Investments        NaN
# Other Short Term Investments                            NaN
# Cash And Cash Equivalents                               NaN
# Cash Equivalents                                        NaN
# Cash Financial                                          NaN
#
# [69 rows x 7 columns]

# %% [markdown]
# ### Estado de resultados anual y trimestral

# %%
# Anual
AAPL.income_stmt
# Out:
#                                                       2024-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  2.410000e-01
# Normalized EBITDA                                   1.346610e+11
# Net Income From Continuing Operation Net Minori...  9.373600e+10
# Reconciled Depreciation                             1.144500e+10
# Reconciled Cost Of Revenue                          2.103520e+11
# EBITDA                                              1.346610e+11
# EBIT                                                1.232160e+11
# Net Interest Income                                          NaN
# Interest Expense                                             NaN
# Interest Income                                              NaN
# Normalized Income                                   9.373600e+10
# Net Income From Continuing And Discontinued Ope...  9.373600e+10
# Total Expenses                                      2.678190e+11
# Total Operating Income As Reported                  1.232160e+11
# Diluted Average Shares                              1.540810e+10
# Basic Average Shares                                1.534378e+10
# Diluted EPS                                         6.080000e+00
# Basic EPS                                           6.110000e+00
# Diluted NI Availto Com Stockholders                 9.373600e+10
# Net Income Common Stockholders                      9.373600e+10
# Net Income                                          9.373600e+10
# Net Income Including Noncontrolling Interests       9.373600e+10
# Net Income Continuous Operations                    9.373600e+10
# Tax Provision                                       2.974900e+10
# Pretax Income                                       1.234850e+11
# Other Income Expense                                2.690000e+08
# Other Non Operating Income Expenses                 2.690000e+08
# Net Non Operating Interest Income Expense                    NaN
# Interest Expense Non Operating                               NaN
# Interest Income Non Operating                                NaN
# Operating Income                                    1.232160e+11
# Operating Expense                                   5.746700e+10
# Research And Development                            3.137000e+10
# Selling General And Administration                  2.609700e+10
# Gross Profit                                        1.806830e+11
# Cost Of Revenue                                     2.103520e+11
# Total Revenue                                       3.910350e+11
# Operating Revenue                                   3.910350e+11
#
#                                                       2023-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.470000e-01
# Normalized EBITDA                                   1.258200e+11
# Net Income From Continuing Operation Net Minori...  9.699500e+10
# Reconciled Depreciation                             1.151900e+10
# Reconciled Cost Of Revenue                          2.141370e+11
# EBITDA                                              1.258200e+11
# EBIT                                                1.143010e+11
# Net Interest Income                                -1.830000e+08
# Interest Expense                                    3.933000e+09
# Interest Income                                     3.750000e+09
# Normalized Income                                   9.699500e+10
# Net Income From Continuing And Discontinued Ope...  9.699500e+10
# Total Expenses                                      2.689840e+11
# Total Operating Income As Reported                  1.143010e+11
# Diluted Average Shares                              1.581255e+10
# Basic Average Shares                                1.574423e+10
# Diluted EPS                                         6.130000e+00
# Basic EPS                                           6.160000e+00
# Diluted NI Availto Com Stockholders                 9.699500e+10
# Net Income Common Stockholders                      9.699500e+10
# Net Income                                          9.699500e+10
# Net Income Including Noncontrolling Interests       9.699500e+10
# Net Income Continuous Operations                    9.699500e+10
# Tax Provision                                       1.674100e+10
# Pretax Income                                       1.137360e+11
# Other Income Expense                               -5.650000e+08
# Other Non Operating Income Expenses                -5.650000e+08
# Net Non Operating Interest Income Expense          -1.830000e+08
# Interest Expense Non Operating                      3.933000e+09
# Interest Income Non Operating                       3.750000e+09
# Operating Income                                    1.143010e+11
# Operating Expense                                   5.484700e+10
# Research And Development                            2.991500e+10
# Selling General And Administration                  2.493200e+10
# Gross Profit                                        1.691480e+11
# Cost Of Revenue                                     2.141370e+11
# Total Revenue                                       3.832850e+11
# Operating Revenue                                   3.832850e+11
#
#                                                       2022-09-30    2021-09-30
# Tax Effect Of Unusual Items                         0.000000e+00  0.000000e+00
# Tax Rate For Calcs                                  1.620000e-01  1.330000e-01
# Normalized EBITDA                                   1.305410e+11  1.231360e+11
# Net Income From Continuing Operation Net Minori...  9.980300e+10  9.468000e+10
# Reconciled Depreciation                             1.110400e+10  1.128400e+10
# Reconciled Cost Of Revenue                          2.235460e+11  2.129810e+11
# EBITDA                                              1.305410e+11  1.231360e+11
# EBIT                                                1.194370e+11  1.118520e+11
# Net Interest Income                                -1.060000e+08  1.980000e+08
# Interest Expense                                    2.931000e+09  2.645000e+09
# Interest Income                                     2.825000e+09  2.843000e+09
# Normalized Income                                   9.980300e+10  9.468000e+10
# Net Income From Continuing And Discontinued Ope...  9.980300e+10  9.468000e+10
# Total Expenses                                      2.748910e+11  2.568680e+11
# Total Operating Income As Reported                  1.194370e+11  1.089490e+11
# Diluted Average Shares                              1.632582e+10  1.686492e+10
# Basic Average Shares                                1.621596e+10  1.670127e+10
# Diluted EPS                                         6.110000e+00  5.610000e+00
# Basic EPS                                           6.150000e+00  5.670000e+00
# Diluted NI Availto Com Stockholders                 9.980300e+10  9.468000e+10
# Net Income Common Stockholders                      9.980300e+10  9.468000e+10
# Net Income                                          9.980300e+10  9.468000e+10
# Net Income Including Noncontrolling Interests       9.980300e+10  9.468000e+10
# Net Income Continuous Operations                    9.980300e+10  9.468000e+10
# Tax Provision                                       1.930000e+10  1.452700e+10
# Pretax Income                                       1.191030e+11  1.092070e+11
# Other Income Expense                               -3.340000e+08  6.000000e+07
# Other Non Operating Income Expenses                -3.340000e+08  6.000000e+07
# Net Non Operating Interest Income Expense          -1.060000e+08  1.980000e+08
# Interest Expense Non Operating                      2.931000e+09  2.645000e+09
# Interest Income Non Operating                       2.825000e+09  2.843000e+09
# Operating Income                                    1.194370e+11  1.089490e+11
# Operating Expense                                   5.134500e+10  4.388700e+10
# Research And Development                            2.625100e+10  2.191400e+10
# Selling General And Administration                  2.509400e+10  2.197300e+10
# Gross Profit                                        1.707820e+11  1.528360e+11
# Cost Of Revenue                                     2.235460e+11  2.129810e+11
# Total Revenue                                       3.943280e+11  3.658170e+11
# Operating Revenue                                   3.943280e+11  3.658170e+11

# %%
# Trimestral
AAPL.quarterly_income_stmt
# Out:
#                                                       2025-06-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.640000e-01
# Normalized EBITDA                                   3.103200e+10
# Net Income From Continuing Operation Net Minori...  2.343400e+10
# Reconciled Depreciation                             2.830000e+09
# Reconciled Cost Of Revenue                          5.031800e+10
# EBITDA                                              3.103200e+10
# EBIT                                                2.820200e+10
# Normalized Income                                   2.343400e+10
# Net Income From Continuing And Discontinued Ope...  2.343400e+10
# Total Expenses                                      6.583400e+10
# Total Operating Income As Reported                  2.820200e+10
# Diluted Average Shares                              1.494818e+10
# Basic Average Shares                                1.490289e+10
# Diluted EPS                                         1.570000e+00
# Basic EPS                                           1.570000e+00
# Diluted NI Availto Com Stockholders                 2.343400e+10
# Net Income Common Stockholders                      2.343400e+10
# Net Income                                          2.343400e+10
# Net Income Including Noncontrolling Interests       2.343400e+10
# Net Income Continuous Operations                    2.343400e+10
# Tax Provision                                       4.597000e+09
# Pretax Income                                       2.803100e+10
# Other Income Expense                               -1.710000e+08
# Other Non Operating Income Expenses                -1.710000e+08
# Operating Income                                    2.820200e+10
# Operating Expense                                   1.551600e+10
# Research And Development                            8.866000e+09
# Selling General And Administration                  6.650000e+09
# Gross Profit                                        4.371800e+10
# Cost Of Revenue                                     5.031800e+10
# Total Revenue                                       9.403600e+10
# Operating Revenue                                   9.403600e+10
#
#                                                       2025-03-31  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.550000e-01
# Normalized EBITDA                                   3.225000e+10
# Net Income From Continuing Operation Net Minori...  2.478000e+10
# Reconciled Depreciation                             2.661000e+09
# Reconciled Cost Of Revenue                          5.049200e+10
# EBITDA                                              3.225000e+10
# EBIT                                                2.958900e+10
# Normalized Income                                   2.478000e+10
# Net Income From Continuing And Discontinued Ope...  2.478000e+10
# Total Expenses                                      6.577000e+10
# Total Operating Income As Reported                  2.958900e+10
# Diluted Average Shares                              1.505613e+10
# Basic Average Shares                                1.499408e+10
# Diluted EPS                                         1.650000e+00
# Basic EPS                                           1.650000e+00
# Diluted NI Availto Com Stockholders                 2.478000e+10
# Net Income Common Stockholders                      2.478000e+10
# Net Income                                          2.478000e+10
# Net Income Including Noncontrolling Interests       2.478000e+10
# Net Income Continuous Operations                    2.478000e+10
# Tax Provision                                       4.530000e+09
# Pretax Income                                       2.931000e+10
# Other Income Expense                               -2.790000e+08
# Other Non Operating Income Expenses                -2.790000e+08
# Operating Income                                    2.958900e+10
# Operating Expense                                   1.527800e+10
# Research And Development                            8.550000e+09
# Selling General And Administration                  6.728000e+09
# Gross Profit                                        4.486700e+10
# Cost Of Revenue                                     5.049200e+10
# Total Revenue                                       9.535900e+10
# Operating Revenue                                   9.535900e+10
#
#                                                       2024-12-31  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.470000e-01
# Normalized EBITDA                                   4.591200e+10
# Net Income From Continuing Operation Net Minori...  3.633000e+10
# Reconciled Depreciation                             3.080000e+09
# Reconciled Cost Of Revenue                          6.602500e+10
# EBITDA                                              4.591200e+10
# EBIT                                                4.283200e+10
# Normalized Income                                   3.633000e+10
# Net Income From Continuing And Discontinued Ope...  3.633000e+10
# Total Expenses                                      8.146800e+10
# Total Operating Income As Reported                  4.283200e+10
# Diluted Average Shares                              1.515086e+10
# Basic Average Shares                                1.508172e+10
# Diluted EPS                                         2.400000e+00
# Basic EPS                                           2.410000e+00
# Diluted NI Availto Com Stockholders                 3.633000e+10
# Net Income Common Stockholders                      3.633000e+10
# Net Income                                          3.633000e+10
# Net Income Including Noncontrolling Interests       3.633000e+10
# Net Income Continuous Operations                    3.633000e+10
# Tax Provision                                       6.254000e+09
# Pretax Income                                       4.258400e+10
# Other Income Expense                               -2.480000e+08
# Other Non Operating Income Expenses                -2.480000e+08
# Operating Income                                    4.283200e+10
# Operating Expense                                   1.544300e+10
# Research And Development                            8.268000e+09
# Selling General And Administration                  7.175000e+09
# Gross Profit                                        5.827500e+10
# Cost Of Revenue                                     6.602500e+10
# Total Revenue                                       1.243000e+11
# Operating Revenue                                   1.243000e+11
#
#                                                       2024-09-30    2024-06-30
# Tax Effect Of Unusual Items                         0.000000e+00  0.000000e+00
# Tax Rate For Calcs                                  2.100000e-01  1.590000e-01
# Normalized EBITDA                                   3.250200e+10  2.820200e+10
# Net Income From Continuing Operation Net Minori...  1.473600e+10  2.144800e+10
# Reconciled Depreciation                             2.911000e+09  2.850000e+09
# Reconciled Cost Of Revenue                          5.105100e+10  4.609900e+10
# EBITDA                                              3.250200e+10  2.820200e+10
# EBIT                                                2.959100e+10  2.535200e+10
# Normalized Income                                   1.473600e+10  2.144800e+10
# Net Income From Continuing And Discontinued Ope...  1.473600e+10  2.144800e+10
# Total Expenses                                      6.533900e+10  6.042500e+10
# Total Operating Income As Reported                  2.959100e+10  2.535200e+10
# Diluted Average Shares                              1.524285e+10  1.534818e+10
# Basic Average Shares                                1.517199e+10  1.528752e+10
# Diluted EPS                                         9.700000e-01  1.400000e+00
# Basic EPS                                           9.700000e-01  1.400000e+00
# Diluted NI Availto Com Stockholders                 1.473600e+10  2.144800e+10
# Net Income Common Stockholders                      1.473600e+10  2.144800e+10
# Net Income                                          1.473600e+10  2.144800e+10
# Net Income Including Noncontrolling Interests       1.473600e+10  2.144800e+10
# Net Income Continuous Operations                    1.473600e+10  2.144800e+10
# Tax Provision                                       1.487400e+10  4.046000e+09
# Pretax Income                                       2.961000e+10  2.549400e+10
# Other Income Expense                                1.900000e+07  1.420000e+08
# Other Non Operating Income Expenses                 1.900000e+07  1.420000e+08
# Operating Income                                    2.959100e+10  2.535200e+10
# Operating Expense                                   1.428800e+10  1.432600e+10
# Research And Development                            7.765000e+09  8.006000e+09
# Selling General And Administration                  6.523000e+09  6.320000e+09
# Gross Profit                                        4.387900e+10  3.967800e+10
# Cost Of Revenue                                     5.105100e+10  4.609900e+10
# Total Revenue                                       9.493000e+10  8.577700e+10
# Operating Revenue                                   9.493000e+10  8.577700e+10

# %% [markdown]
# ### Noticias

# %%
AAPL.news[0]
# Out:
# {'id': '3802e40b-bbaa-3e34-9ef3-1217a7b4f7f2',
#  'content': {'id': '3802e40b-bbaa-3e34-9ef3-1217a7b4f7f2',
#   'contentType': 'VIDEO',
#   'title': 'Apple, Rumble-Perplexity gains, Roblox: Trending Tickers',
#   'description': '<p>Market Catalysts host <a data-i13n="cpos:1;pos:1" href="https://www.yahoo.com/author/julie-hyman/?.tsrc=fin-srch">Julie Hyman</a> tracks several of the day\'s top trending stock tickers, including iPhone maker Apple (<a data-i13n="cpos:2;pos:1" href="https://finance.yahoo.com/quote/AAPL">AAPL</a>) receiving a downgrade, Rumble\'s (<a data-i13n="cpos:3;pos:1" href="https://finance.yahoo.com/quote/RUM">RUM</a>) stock gains tied to its partnership with Perplexity (<a data-i13n="cpos:4;pos:1" href="https://finance.yahoo.com/quote/PEAI.PVT">PEAI.PVT</a>), and Roblox (<a data-i13n="cpos:5;pos:1" href="https://finance.yahoo.com/quote/RBLX">RBLX</a>) seeing a slowdown in US bookings growth.</p>\n<p>To watch more expert insights and analysis on the latest market action, check out more\xa0<a data-i13n="cpos:6;pos:1" href="https://finance.yahoo.com/videos/series/market-catalysts/">Market Catalysts</a>.</p>',
#   'summary': "Market Catalysts host Julie Hyman tracks several of the day's top trending stock tickers, including iPhone maker Apple (AAPL) receiving a downgrade, Rumble's (RUM) stock gains tied to its partnership with Perplexity (PEAI.PVT), and Roblox (RBLX) seeing a slowdown in US bookings growth. To watch more expert insights and analysis on the latest market action, check out more&nbsp;Market Catalysts.",
#   'pubDate': '2025-10-03T14:56:00Z',
#   'displayTime': '',
#   'isHosted': True,
#   'bypassModal': False,
#   'previewUrl': None,
#   'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-uploaded-images/2025-10/ba2d6c20-a067-11f0-bdcf-359b78f3a285',
#    'originalWidth': 1435,
#    'originalHeight': 806,
#    'caption': '',
#    'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Gg4eVBW4DILCxUe.yepxsQ--~B/aD04MDY7dz0xNDM1O2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2025-10/ba2d6c20-a067-11f0-bdcf-359b78f3a285',
#      'width': 1435,
#      'height': 806,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/1FGjZLB8LJMl6ZuHo9JazA--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2025-10/ba2d6c20-a067-11f0-bdcf-359b78f3a285',
#      'width': 170,
#      'height': 128,
#      'tag': '170x128'}]},
#   'provider': {'displayName': 'Yahoo Finance Video',
#    'url': 'https://finance.yahoo.com/'},
#   'canonicalUrl': {'url': 'https://finance.yahoo.com/video/apple-rumble-perplexity-gains-roblox-145600834.html',
#    'site': 'finance',
#    'region': 'US',
#    'lang': 'en-US'},
#   'clickThroughUrl': {'url': 'https://finance.yahoo.com/video/apple-rumble-perplexity-gains-roblox-145600834.html',
#    'site': 'finance',
#    'region': 'US',
#    'lang': 'en-US'},
#   'metadata': {'editorsPick': True},
#   'finance': {'premiumFinance': {'isPremiumNews': False,
#     'isPremiumFreeNews': False}},
#   'storyline': None}}

# %%
AAPL.news[0]['content']['summary']
# Out:
# "Market Catalysts host Julie Hyman tracks several of the day's top trending stock tickers, including iPhone maker Apple (AAPL) receiving a downgrade, Rumble's (RUM) stock gains tied to its partnership with Perplexity (PEAI.PVT), and Roblox (RBLX) seeing a slowdown in US bookings growth. To watch more expert insights and analysis on the latest market action, check out more&nbsp;Market Catalysts."

# %% [markdown]
# ### Fechas expiración opciones

# %%
AAPL.options
# Out:
# ('2025-10-03',
#  '2025-10-10',
#  '2025-10-17',
#  '2025-10-24',
#  '2025-10-31',
#  '2025-11-07',
#  '2025-11-21',
#  '2025-12-19',
#  '2026-01-16',
#  '2026-02-20',
#  '2026-03-20',
#  '2026-04-17',
#  '2026-05-15',
#  '2026-06-18',
#  '2026-08-21',
#  '2026-09-18',
#  '2026-12-18',
#  '2027-01-15',
#  '2027-06-17',
#  '2027-12-17',
#  '2028-01-21')

# %% [markdown]
# Contratos de opciones en una fecha de expiración específica:

# %%
opt = AAPL.option_chain('2025-10-17')
opt.calls.head()
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0  AAPL251017C00090000 2025-10-01 15:14:45+00:00    90.0     165.75  167.35
# 1  AAPL251017C00095000 2025-09-22 18:27:13+00:00    95.0     160.40  162.25
# 2  AAPL251017C00100000 2025-09-19 19:06:45+00:00   100.0     146.12  157.70
# 3  AAPL251017C00105000 2025-07-21 14:02:53+00:00   105.0     110.26  122.40
# 4  AAPL251017C00110000 2025-09-12 13:59:04+00:00   110.0     121.00  147.70
#
#       ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  168.50     0.0            0.0     2.0            23           2.472660
# 1  164.10     0.0            0.0     NaN             2           2.023442
# 2  159.05     0.0            0.0     5.0            20           2.144536
# 3  124.25     0.0            0.0     2.0            14           0.000010
# 4  149.10     0.0            0.0   345.0           462           1.962891
#
#    inTheMoney contractSize currency
# 0        True      REGULAR      USD
# 1        True      REGULAR      USD
# 2        True      REGULAR      USD
# 3        True      REGULAR      USD
# 4        True      REGULAR      USD

# %%
opt.puts
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   AAPL251017P00090000 2025-09-29 13:30:03+00:00    90.0       0.01    0.0
# 1   AAPL251017P00095000 2025-10-01 16:28:23+00:00    95.0       0.01    0.0
# 2   AAPL251017P00100000 2025-09-22 13:46:16+00:00   100.0       0.01    0.0
# 3   AAPL251017P00105000 2025-09-12 15:56:38+00:00   105.0       0.02    0.0
# 4   AAPL251017P00110000 2025-09-22 13:55:57+00:00   110.0       0.01    0.0
# ..                  ...                       ...     ...        ...    ...
# 57  AAPL251017P00330000 2025-08-15 19:50:00+00:00   330.0      98.75   95.7
# 58  AAPL251017P00335000 2025-09-19 18:25:35+00:00   335.0      89.55   76.6
# 59  AAPL251017P00355000 2025-04-11 19:46:36+00:00   355.0     157.02    0.0
# 60  AAPL251017P00360000 2025-04-11 19:46:36+00:00   360.0     162.01    0.0
# 61  AAPL251017P00370000 2025-07-18 13:52:01+00:00   370.0     159.95  141.9
#
#        ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0     0.01     0.0            0.0     6.0           955           1.562502
# 1     0.01     0.0            0.0     1.0          1135           1.468753
# 2     0.01     0.0            0.0     3.0           860           1.406253
# 3     0.01     0.0            0.0     1.0           292           1.312503
# 4     0.01     0.0            0.0     5.0           615           1.250004
# ..     ...     ...            ...     ...           ...                ...
# 57   96.25     0.0            0.0     NaN             0           2.229130
# 58   77.25     0.0            0.0     5.0             0           0.625980
# 59    0.00     0.0            0.0     NaN             0           0.000010
# 60    0.00     0.0            0.0     NaN             0           0.000010
# 61  142.50     0.0            0.0     NaN             0           2.946536
#
#     inTheMoney contractSize currency
# 0        False      REGULAR      USD
# 1        False      REGULAR      USD
# 2        False      REGULAR      USD
# 3        False      REGULAR      USD
# 4        False      REGULAR      USD
# ..         ...          ...      ...
# 57        True      REGULAR      USD
# 58        True      REGULAR      USD
# 59        True      REGULAR      USD
# 60        True      REGULAR      USD
# 61        True      REGULAR      USD
#
# [62 rows x 14 columns]
